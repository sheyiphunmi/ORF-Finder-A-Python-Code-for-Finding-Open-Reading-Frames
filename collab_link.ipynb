# %%
from google.colab import drive
drive.mount('/content/drive')
genome = "MT_genome.fasta"
script_name = "find_orfs_1.py"
genetic_code = "my_code.txt"
# Copy genome files and the python script from your Google drive
# !cp /content/drive/MyDrive/intro2bioinfo/$genome .
# !cp /content/drive/MyDrive/intro2bioinfo/$script_name .
# !cp /content/drive/MyDrive/intro2bioinfo/$genetic_code .
# Run the script to find orfs
# !python $script_name $genome $genetic_code #> output.txt
#!head -45 output.txt
# copy output files you care about back to your drive
# !cp orf_all.txt /content/drive/MyDrive/intro2bioinfo/.
# !cp top_13_orf_all.txt /content/drive/MyDrive/intro2bioinfo/.
# !cp top_15_orf_all.txt /content/drive/MyDrive/intro2bioinfo/.
# !cp top_18_orf_all.txt /content/drive/MyDrive/intro2bioinfo/.
# !cp top_21_orf_all.txt /content/drive/MyDrive/intro2bioinfo/.
# Out:
# Mounted at /content/drive
# INFO:
# START CODON USED: ATG
# INFO:
# Searching for ORFs in reading frame 1
# INFO: ORF found at 3312 4260
# INFO: ORF found at 8526 9204
# INFO: ORF found at 12342 14145
# INFO: ORF found at 16086 16314
# INFO: ORF found at 18465 18987
# INFO:
# Searching for ORFs in reading frame 2
# INFO: ORF found at 7585 8266
# INFO: ORF found at 8365 8569
# INFO: ORF found at 10759 12181
# INFO: ORF found at 14746 15904
# INFO:
# Searching for ORFs in reading frame 3
# INFO: ORF found at 4577 5510
# INFO: ORF found at 5903 7442
# INFO: ORF found at 9206 10052
# INFO: ORF found at 10322 10763
# INFO:
# START CODON USED: ATA
# INFO:
# Searching for ORFs in reading frame 1
# INFO: ORF found at 537 831
# INFO: ORF found at 3306 4260
# INFO: ORF found at 12327 14145
# INFO: ORF found at 18462 18987
# INFO:
# Searching for ORFs in reading frame 2
# INFO:
# Searching for ORFs in reading frame 3
# INFO: ORF found at 4043 4262
# INFO: ORF found at 4571 5510
# ...
